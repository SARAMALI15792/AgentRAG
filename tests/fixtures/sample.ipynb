# %%
# CODE_SENTINEL
import agentrag

result = agentrag.ingest('sample.txt')
print(result)

# %% [markdown]
# ## MARKDOWN_SENTINEL
#
# This notebook demonstrates the AgentRAG ingestion pipeline.
# Run the cells in order to ingest a document and search over it.

# %%
# Second code cell — semantic search
results = agentrag.search('what is the ingestion pipeline?', top_k=5)
for r in results:
    print(r.score, r.text[:80])

# %% [markdown]
# ## Results
#
# The search returns ranked chunks from the embedded Qdrant store.
# Each result includes a semantic similarity score and the chunk text.

# %% [raw]
# RAW_SENTINEL: this raw cell should be excluded from ingestion output.
